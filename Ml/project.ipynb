# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# import sklearn
import matplotlib.pyplot as plt

# %%
housing_dataframe= pd.read_csv('ccn.csv')

# %%
# display all
housing_dataframe
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7229300521  20141013T000000  231300.0       2.0       1.00
# 1      6414100192  20141209T000000  538000.0       3.0       2.25
# 2      5631500400  20150225T000000  180000.0       2.0       1.00
# 3      2487200875  20141209T000000  604000.0       4.0       3.00
# 4      1954400510  20150218T000000  510000.0       3.0       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0       3.0       2.50
# 21609  6600060120  20150223T000000  400000.0       4.0       2.50
# 21610  1523300141  20140623T000000  402101.0       2.0       0.75
# 21611   291310100  20150116T000000  400000.0       3.0       2.50
# 21612  1523300157  20141015T000000  325000.0       2.0       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0           1180.0    5650.0     1.0           0     0  ...      7
# ...

# %%
# display 1st five data
housing_dataframe.head
# Out:
# <bound method NDFrame.head of                id             date     price  bedrooms  bathrooms  \
# 0      7229300521  20141013T000000  231300.0       2.0       1.00
# 1      6414100192  20141209T000000  538000.0       3.0       2.25
# 2      5631500400  20150225T000000  180000.0       2.0       1.00
# 3      2487200875  20141209T000000  604000.0       4.0       3.00
# 4      1954400510  20150218T000000  510000.0       3.0       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0       3.0       2.50
# 21609  6600060120  20150223T000000  400000.0       4.0       2.50
# 21610  1523300141  20140623T000000  402101.0       2.0       0.75
# 21611   291310100  20150116T000000  400000.0       3.0       2.50
# 21612  1523300157  20141015T000000  325000.0       2.0       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0           1180.0    5650.0     1.0           0     0  ...      7
# ...

# %%
# display 1st 10 data
housing_dataframe.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7229300521  20141013T000000   231300.0       2.0       1.00       1180.0
# 1  6414100192  20141209T000000   538000.0       3.0       2.25          NaN
# 2  5631500400  20150225T000000   180000.0       2.0       1.00        770.0
# 3  2487200875  20141209T000000   604000.0       4.0       3.00       1960.0
# 4  1954400510  20150218T000000   510000.0       3.0       2.00       1680.0
# 5  7237550310  20140512T000000  1225000.0       4.0       4.50       5420.0
# 6  1321400060              NaN   257500.0       3.0       2.25       1715.0
# 7  2008000270              NaN   291850.0       3.0       1.50       1060.0
# 8  2414600126  20150415T000000   229500.0       3.0       1.00       1780.0
# 9  3793500160  20150312T000000   323000.0       3.0       2.50       1890.0
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
# display last 5 data
housing_dataframe.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0       3.0       2.50
# 21609  6600060120  20150223T000000  400000.0       4.0       2.50
# 21610  1523300141  20140623T000000  402101.0       2.0       0.75
# 21611   291310100  20150116T000000  400000.0       3.0       2.50
# 21612  1523300157  20141015T000000  325000.0       2.0       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608       1530.0    1131.0     3.0           0     0  ...      8
# 21609       2310.0    5813.0     2.0           0     0  ...      8
# 21610       1020.0    1350.0     2.0           0     0  ...      7
# 21611       1600.0    2388.0     2.0           0     0  ...      8
# 21612       1020.0    1076.0     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608      1530.0            0.0      2009             0  98103.0  47.6993
# ...

# %%
# display statical summary of data
housing_dataframe.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161200e+04  21612.000000  21613.000000  21609.000000
# mean   4.580306e+09  5.400835e+05      3.370813      2.114757   2079.930261
# std    2.876570e+09  3.671346e+05      0.930123      0.770163    918.507812
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.218375e+05      3.000000      1.750000   1425.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161100e+04  21608.000000  21613.000000  21613.000000  21613.000000
# mean   1.510780e+04      1.494331      0.007542      0.234303      3.409430
# ...

# %%
# to show datatype and not null count and col
housing_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21610 non-null  object
#  2   price          21612 non-null  float64
#  3   bedrooms       21612 non-null  float64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21609 non-null  float64
#  6   sqft_lot       21611 non-null  float64
#  7   floors         21608 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21611 non-null  float64
#  13  sqft_basement  21612 non-null  float64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21612 non-null  float64
# ...

# %% [markdown]
# ### Data Processing/Data wrangling

# %%
# display total null value in each col
housing_dataframe.isnull().sum()
# Out:
# id               0
# date             3
# price            1
# bedrooms         1
# bathrooms        0
# sqft_living      4
# sqft_lot         2
# floors           5
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       2
# sqft_basement    1
# yr_built         0
# yr_renovated     0
# zipcode          1
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64
